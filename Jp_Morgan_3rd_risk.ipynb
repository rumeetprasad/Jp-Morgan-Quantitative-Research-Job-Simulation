# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
import ipywidgets as widgets
from IPython.display import display

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv("Task 3 and 4_Loan_Data.csv",index_col="customer_id")
df.head()
# Out:
#              credit_lines_outstanding  loan_amt_outstanding  \
# customer_id
# 8153374                             0           5221.545193
# 7442532                             5           1958.928726
# 2256073                             0           3363.009259
# 4885975                             0           4766.648001
# 4700614                             1           1345.827718
#
#              total_debt_outstanding       income  years_employed  fico_score  \
# customer_id
# 8153374                 3915.471226  78039.38546               5         605
# 7442532                 8228.752520  26648.43525               2         572
# 2256073                 2027.830850  65866.71246               4         602
# 4885975                 2501.730397  74356.88347               5         612
# 4700614                 1768.826187  23448.32631               6         631
#
#              default
# customer_id
# 8153374            0
# 7442532            1
# 2256073            0
# 4885975            0
# 4700614            0

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# select features and label
X = df[['credit_lines_outstanding', 'loan_amt_outstanding',
        'total_debt_outstanding', 'income', 'years_employed', 'fico_score']]

y = df['default']

# train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
a=0

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
import ipywidgets as widgets
from IPython.display import display

from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay, \
                            precision_score, recall_score, f1_score, roc_auc_score,roc_curve 
models={
    "Logisitic Regression":LogisticRegression(),
    "Decision Tree":DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier(),
    "Gradient Boost":GradientBoostingClassifier(),
    "Adaboost":AdaBoostClassifier(),
    "Extreme Gradient Boost":XGBClassifier()
}
for i in range(len(list(models))):
    el=[]
    a=0
    tel=0
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted') # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)
    pd_prob = model.predict_proba(X_test)[:, 1]


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc
    a=0
    for p in pd_prob:
        el.append(0.9*df["loan_amt_outstanding"].iloc[a]*p)
        tel=tel+el[a]
        a=a+1
    dropdown = widgets.Dropdown(
    options=el,
    description='EL:',
    disabled=False,
    )
    dropdown1 = widgets.Dropdown(
    options=pd_prob,
    description='Pd_Prob:',
    disabled=False,
    )
    
    display(dropdown)
    display(dropdown1)


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))
    

    
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))
    print("The total expected loss is:",tel)
    

    
    print('='*35)
    print('\n')
# Out:
# Dropdown(description='EL:', options=(np.float64(5.743479509345476e-13), np.float64(1.348601327399737), np.floa…
# Dropdown(description='Pd_Prob:', options=(np.float64(1.222175364454947e-16), np.float64(0.0007649313114075193)…
# Logisitic Regression
# Model performance for Training set
# - Accuracy: 0.9951
# - F1 score: 0.9951
# - Precision: 0.9900
# - Recall: 0.9840
# - Roc Auc Score: 0.9908
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9947
# - F1 score: 0.9946
# - Precision: 0.9944
# - Recall: 0.9760
# - Roc Auc Score: 0.9874
# The total expected loss is: 1962838.87264611
# ===================================
# Dropdown(description='EL:', options=(np.float64(0.0), np.float64(0.0), np.float64(3026.7083331), np.float64(0.…
# Dropdown(description='Pd_Prob:', options=(np.float64(0.0), np.float64(0.0), np.float64(1.0), np.float64(0.0), …
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9947
# - F1 score: 0.9947
# - Precision: 0.9870
# - Recall: 0.9834
# - Roc Auc Score: 0.9903
# The total expected loss is: 1989323.0791649106
# ===================================
# Dropdown(description='EL:', options=(np.float64(0.0), np.float64(176.30358534000004), np.float64(3026.7083331)…
# Dropdown(description='Pd_Prob:', options=(np.float64(0.0), np.float64(0.1), np.float64(1.0), np.float64(0.0), …
# Random Forest
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9950
# - F1 score: 0.9950
# - Precision: 0.9888
# - Recall: 0.9834
# - Roc Auc Score: 0.9905
# The total expected loss is: 2001458.529688115
# ===================================
# Dropdown(description='EL:', options=(np.float64(1.2380279489694965), np.float64(50.91501870906112), np.float64…
# Dropdown(description='Pd_Prob:', options=(np.float64(0.0002634443558604487), np.float64(0.028879173733688923),…
# Gradient Boost
# Model performance for Training set
# - Accuracy: 0.9984
# - F1 score: 0.9984
# - Precision: 0.9962
# - Recall: 0.9954
# - Roc Auc Score: 0.9973
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9963
# - F1 score: 0.9963
# - Precision: 0.9926
# - Recall: 0.9871
# - Roc Auc Score: 0.9927
# The total expected loss is: 1984836.3999809485
# ===================================
# Dropdown(description='EL:', options=(np.float64(889.3784796971015), np.float64(658.111236050432), np.float64(2…
# Dropdown(description='Pd_Prob:', options=(np.float64(0.18925399939070436), np.float64(0.3732829566575574), np.…
# Adaboost
# Model performance for Training set
# - Accuracy: 0.9973
# - F1 score: 0.9973
# - Precision: 0.9962
# - Recall: 0.9893
# - Roc Auc Score: 0.9942
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9933
# - F1 score: 0.9933
# - Precision: 0.9851
# - Recall: 0.9778
# - Roc Auc Score: 0.9873
# The total expected loss is: 3561991.4144631936
# ===================================
# Dropdown(description='EL:', options=(np.float64(0.01007014917811944), np.float64(1.4460284911317962), np.float…
# Dropdown(description='Pd_Prob:', options=(np.float32(2.1428627e-06), np.float32(0.00082019233), np.float32(0.9…
# Extreme Gradient Boost
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9957
# - F1 score: 0.9957
# - Precision: 0.9889
# - Recall: 0.9871
# - Roc Auc Score: 0.9923
# The total expected loss is: 1983426.6562707566
# ===================================
